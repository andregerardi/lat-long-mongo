# %% [markdown]
# ### Consulta dados MongoDB

# %% [markdown]
# #### Verifica o ping

# %%
#%pip install "pymongo[srv]==3.12"
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://andregerardi3:nxzsRUOe5SJQqSoT@lat-long-superacao.vs4vhop.mongodb.net/lat-long-superacao?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# #### verifica os dados inseridos

# %%
# lista bancos (exclui system dbs)
user_dbs = [d for d in client.list_database_names() if d not in ('admin', 'local', 'config')]
print("Databases:", user_dbs)

# escolhe o primeiro banco de usuário encontrado (ou altere para o nome desejado)
if not user_dbs:
    print("Nenhum banco de usuário encontrado.")
else:
    db = client[user_dbs[0]]
    print("Usando DB:", db.name)
    cols = db.list_collection_names()
    print("Collections:", cols)

    # para cada coleção, mostra contagem, um documento de exemplo e os primeiros 10 documentos
    for coll_name in cols:
        coll = db[coll_name]
        print(f"\nCollection: {coll_name}")
        print("Count:", coll.count_documents({}))
        print("Sample doc:", coll.find_one())
        print("First 10 docs:")
        for doc in coll.find().limit(10):
            print(doc)
# Out:
# Databases: ['lat-long-superacao']
# Usando DB: lat-long-superacao
# Collections: ['locations']
#
# Collection: locations
# Count: 1
# Sample doc: {'_id': ObjectId('6941435eb7b9a6896e962493'), 'latitude': -23.560192, 'longitude': -46.641971, 'timestamp': datetime.datetime(2025, 12, 16, 11, 32, 46, 552000), 'agent_name': 'Ana Luisa da Silva Capim', 'municipio': 'Barueri', 'observacoes': 'Essa casa fica ao lado da 302', 'accuracy': 40968.668288017536, 'altitude': None, 'speed': None}
# First 10 docs:
# {'_id': ObjectId('6941435eb7b9a6896e962493'), 'latitude': -23.560192, 'longitude': -46.641971, 'timestamp': datetime.datetime(2025, 12, 16, 11, 32, 46, 552000), 'agent_name': 'Ana Luisa da Silva Capim', 'municipio': 'Barueri', 'observacoes': 'Essa casa fica ao lado da 302', 'accuracy': 40968.668288017536, 'altitude': None, 'speed': None}

# %%
#//agora quero ver o json com o primeiro documento da coleção
import json
first_doc = coll.find_one()
print("First document as JSON:")
print(json.dumps(first_doc, indent=4, default=str))
# Out:
# First document as JSON:
# {
#     "_id": "6941435eb7b9a6896e962493",
#     "latitude": -23.560192,
#     "longitude": -46.641971,
#     "timestamp": "2025-12-16 11:32:46.552000",
#     "agent_name": "Ana Luisa da Silva Capim",
#     "municipio": "Barueri",
#     "observacoes": "Essa casa fica ao lado da 302",
#     "accuracy": 40968.668288017536,
#     "altitude": null,
#     "speed": null
# }

# %%
second_doc = next(coll.find().skip(1).limit(1), None)
if second_doc is None:
    print("No second document found.")
else:
    print("Second document as JSON:")
    print(json.dumps(second_doc, indent=4, default=str))
# Out:
# No second document found.

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.getenv("MONGO_URI"))
# Out:
# mongodb+srv://andregerardi3:nxzsRUOe5SJQqSoT@lat-long-superacao.vs4vhop.mongodb.net/?appName=lat-long-superacao

# %%
from pathlib import Path
load_dotenv(Path(__file__).resolve().parent / ".env")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from pathlib import Path
# ----> 2 load_dotenv(Path(__file__).resolve().parent / ".env")
#
# NameError: name '__file__' is not defined
